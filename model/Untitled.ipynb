# %%
import pandas as pd
from gdp_forecast import forecast_country

df1 = pd.read_csv("../data/gdp_data.csv")

forecast, model = forecast_country(df1, "USA", 10)

model.plot(forecast)
# Out:
# 12:39:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:39:30 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\hp\anaconda3\Lib\site-packages\prophet\forecaster.py:1875: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   dates = pd.date_range(
